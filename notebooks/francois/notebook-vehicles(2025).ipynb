# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nov24-bds-roadies-users/vehicules-2019.csv
# /kaggle/input/nov24-bds-roadies-users/vehicules-2022.csv
# /kaggle/input/nov24-bds-roadies-users/vehicules-2021.csv
# /kaggle/input/nov24-bds-roadies-users/vehicules-2020.csv
# /kaggle/input/nov24-bds-roadies-users/vehicules-2023.csv
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/__script__.py
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/tzdata-2024.2-py2.py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/pydantic_core-2.27.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/polars-1.19.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/statsmodels-0.14.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/llvmlite-0.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/htmlmin-0.1.12.tar.gz
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/urllib3-2.3.0-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/certifi-2024.12.14-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/ydata_profiling-4.12.1-py2.py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/pillow-11.1.0-cp310-cp310-manylinux_2_28_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/typeguard-4.4.1-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/tqdm-4.67.1-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/wordcloud-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/ImageHash-4.3.1-py2.py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/attrs-24.3.0-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/dacite-1.8.1-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/__results__.html
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/patsy-1.0.1-py2.py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/seaborn-0.13.2-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/annotated_types-0.7.0-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/cycler-0.12.1-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/charset_normalizer-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/idna-3.10-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/pyparsing-3.2.1-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/input_requirements.txt
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/networkx-3.4.2-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/numpy-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/six-1.17.0-py2.py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/visions-0.7.6-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/tenacity-9.0.0-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/python_dateutil-2.9.0.post0-py2.py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/__script__.ipynb
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/numba-0.60.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/scipy-1.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/multimethod-1.12-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/et_xmlfile-2.0.0-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/requests-2.32.3-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/plotly-5.24.1-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/__output__.json
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/joblib-1.4.2-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/typing_extensions-4.12.2-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/fonttools-4.55.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/jinja2-3.1.5-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/pytz-2024.2-py2.py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/matplotlib-3.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/install_requirements.sh
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/pydantic-2.10.4-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/packaging-24.2-py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/openpyxl-3.1.5-py2.py3-none-any.whl
# /kaggle/input/pm-73480309-at-01-05-2025-14-12-18/custom.css

# %%
# %%time
## all imports
import polars as pl
import pyarrow.parquet as pq
import os
import shutil
import json
from enum import Enum
from datetime import datetime
from ydata_profiling import ProfileReport
from pathlib import Path

#For excel stuff
import openpyxl
from openpyxl.drawing.image import Image


# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Concurrency
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor, as_completed
import time

#  Warnings
import warnings
warnings.filterwarnings('ignore')

# Set random state
random_state = 42
# Set figure size
plt.rcParams["figure.figsize"] = (20, 20)


## Set the static file locactions
filepaths = {'vehicles':
    {
    2019: '/kaggle/input/nov24-bds-roadies-users/vehicules-2019.csv',
    2020: '/kaggle/input/nov24-bds-roadies-users/vehicules-2020.csv',
    2021: '/kaggle/input/nov24-bds-roadies-users/vehicules-2021.csv',
    2022: '/kaggle/input/nov24-bds-roadies-users/vehicules-2022.csv',
    2023: '/kaggle/input/nov24-bds-roadies-users/vehicules-2023.csv',
    },
    'users':{},
    'places': {},
    'characteristics':{}
             
}
# Out:
# CPU times: user 3.41 s, sys: 778 ms, total: 4.19 s
# Wall time: 6.2 s

# %%
class ExtensionMethods:
    @staticmethod
    def generate_filename(filename=None,extension=None):
        current_datetime = datetime.now()
        f = current_datetime.strftime("%Y_%m_%d_%H%M")
        if (filename is None) or (extension is None):
            return str(f)
        else:
            stitched_f = str(filename)+"_"+str(f)+"."+str(extension)
            return str(stitched_f)

    @staticmethod
    def get_file_name_without_extension(filename):
        if filename == None:
            return "Provide a file"
        return Path(filename).stem

# %%
# %%time
## I want to enummify the metadata to make it human readable . TODO perhaps make a data struct 
class Vehicle_Enum(Enum):

    class Num_Acc(Enum): ## Not the best method since Nummm_ACC are not cat values
        '''The Index/Number of the Crash follows the pattern yyyyxxxxx and is the index column''' 
        @classmethod
        def IsCategory(cls):
            return (True if len(cls.__members__)>0 else False)

    class id_vehicule(Enum):
        '''The vehicle id  in terms of xxx-xxx'''
        @classmethod
        def IsCategory(cls):
            return (True if len(cls.__members__)>0 else False)

    class num_veh(Enum):
        '''The Number of the vehicle category , something in french '''
        @classmethod
        def IsCategory(cls):
            return (True if len(cls.__members__)>0 else False)


    class senc(Enum): # senc DIRECTION OF TRAFFIC
        '''The Direction of Traffic '''
        UNKNOWN = 0 
        PK_INCREASING = 1 #PK ascending or address ascending
        PK_DECREASING = 2
        NO_REFERENCE_POINT = 3
        RANDOM = -1 ##TODO VERIFY THIS
            
        @classmethod
        def IsCategory(cls):
            return (True if len(cls.__members__)>0 else False)
    
    class catv(Enum): # catv Vehicle Category
        '''The Category of Vehicle involved in the crash'''
        UNDETERMINED = 0
        BICYCLE = 1
        MOPED_LESS_EQUAL_50CC = 2
        MICROCAR = 3
        TOURISM_VEHICLE = 7
        UTILITY_VEHICLE_PTAC_1_5T_3_5T = 10 #1.5<PTAC<3.5
        HEAVY_TRUCK_PTAC_3_5T_7_5T = 13
        HEAVY_TRUCK_PTAC_OVER_7_5T = 14
        HEAVY_TRUCK_OVER_3_5T_WITH_TRAILER = 15
        TRACTOR_ONLY = 16
        TRACTOR_WITH_SEMI_TRAILER = 17
        SPECIAL_VEHICLE = 20
        AGRICULTURAL_TRACTOR = 21
        SCOOTER_LESS_EQUAL_50CC = 30
        MOTORCYCLE_50CC_125CC = 31
        SCOOTER_50CC_125CC = 32
        MOTORCYCLE_OVER_125CC = 33
        SCOOTER_OVER_125CC = 34
        LIGHT_QUAD_LESS_EQUAL_50CC = 35
        HEAVY_QUAD_OVER_50CC = 36
        BUS = 37
        COACH = 38
        TRAIN = 39
        TRAMWAY = 40
        THREE_WHEELED_VEHICLE_LESS_EQUAL_50CC = 41
        THREE_WHEELED_VEHICLE_50CC_125CC = 42
        THREE_WHEELED_VEHICLE_OVER_125CC = 43
        MOTORIZED_PERSONAL_TRANSPORT = 50
        NON_MOTORIZED_PERSONAL_TRANSPORT = 60
        OTHER_VEHICLE = 99
        
        @classmethod
        def IsCategory(cls):
            return (True if len(cls.__members__)>0 else False)


    class obs(Enum):  #obs Static ObstacleHit
        ''' The Static/Stationary Obstacle Hit'''
        UNKNOWN = 0
        PARKED_VEHICLE = 1
        TREE_ON_ROADSIDE = 2
        METAL_BARRIER = 3
        CONCRETE_BARRIER = 4
        OTHER_BARRIER=5
        BUILDING_WALL_BRIDGE_PIER = 6 #BUILDING, WALL OR BRIDGE PIER
        VERTICAL_SIGNPOST_OR_EMERGENCY_CALLBOX = 7
        POLE = 8
        URBAN_FURNITURE = 9 # NO CLUE WHAT URBAN FURNITURE
        PARAPET = 10
        REFUGE_ISLAND_BOLLARD = 11 #THE ROAD ISLAND / BOLLARD
        SIDEWALK = 12 #SIDEWALK OR CURB
        DITCH = 13 #DITCH OR EMBANKMENT
        OTHER_OBS_ON_ROADWAY = 14
        OTHER_OBS_ON_SIDEWALK = 15
        ROADWAY_EXIT_WITOUT_OBSTACLES = 16
        AQUEDUCT_HEAD = 17
        
        @classmethod
        def IsCategory(cls):
            return (True if len(cls.__members__)>0 else False)


    class obsm(Enum): #obsm #Mobile obstacle hit
        '''The Dynamic Obstacle Hit'''
        UNKNOWN = 0
        PEDESTRIAN =1 
        VEHICLE = 2
        RAIL_VEHICLE = 3
        ANIMAL_DOMESTIC = 4
        ANIMAL_WILD = 5
        OTHER = 9
        
        @classmethod
        def IsCategory(cls):
            return (True if len(cls.__members__)>0 else False)


    class choc(Enum): #choc Initial Point of Impact
        '''The Initial Point of Impact of the crash'''
        UNKNOWN = 0
        FRONT = 1
        FRONT_LEFT = 2
        FRONT_RIGHT = 3
        REAR = 4
        REAR_RIGHT = 5
        REAR_LEFT = 6
        SIDE_LEFT = 7
        SIDE_RIGHT = 8
        MULTIPLE = 9
    
        @classmethod
        def IsCategory(cls):
            return (True if len(cls.__members__)>0 else False)


    
    class manv(Enum): #manv , Main action before crash
        '''The Main Action performed by the user before the crash'''
        UNKNOWN = 0
        CIRCULATING_NO_DIRECTION_CHANGE =1
        CIRCULATING_SAME_DIRECTION = 2 #SAME DIRECTION SAME LANE
        CIRCULATION_BETWEEN_2_LANES = 3
        CIRCULATING_REVERSING = 4
        CIRCULATING_AGAINTS_FLOW_TRAFFIC = 5
        CIRCULATING_CROSSING_MEDIAN_STRIP = 6
        CIRCULATING_IN_BUSLANE_SAME_DIRECTION = 7
        CIRCULATING_IN_BUSLANE_OPP_DIRECTION = 8
        CIRCULATING_INSERTION =9
        CIRCULATING_TURNING_AROUND_CARRIAGE_WAY = 10
        CHANGING_LANE_LEFT = 11
        CHANGING_LANE_RIGHT = 12
        DEPORT_LEFT = 13
        DEPORT_RIGHT = 14
        TURNING_LEFT = 15
        TURNING_RIGHT = 16
        OVERTAKING_LEFT = 17
        OVERTAKING_RIGHT = 18 
        #VARIOUS S
        CROSSING_ROAD = 19
        PARKING_ACTION = 20
        AVOIDANCE_ACTION = 21
        DOOR_OPENED = 22
        STOP_NO_PARKING = 23
        PARKED_WITH_PASS = 24 # PARKED WITH PASSANGERS
        DRIVING_SIDEWALK = 25
        OTHER_ACTIONS = 26
        
        @classmethod
        def IsCategory(cls):
            return (True if len(cls.__members__)>0 else False)

        
    
    class motor(Enum): # motor
        '''The Type of Motor(In terms of fuel type) involved in the crash'''
        UNKNOWN = 0
        CONVENTIONAL_FUEL = 1 # PETROL, DIESEL ,ETC
        HYBRID_ELECTRIC = 2
        ELECTRIC = 3
        HYDROGEN = 4
        HUMAN_POWERED = 5
        OTHER = 6
        
        @classmethod
        def IsCategory(cls):
            return (True if len(cls.__members__)>0 else False)


    #occ : Number of occupants in the Public transport (bus) including the driver irrespective if they were injured or not
    class occutc(Enum):
        '''Number of occupants in the Public transport (bus) including the driver irrespective if they were injured or not'''
    
        @classmethod
        def IsCategory(cls):
            return (True if len(cls.__members__)>0 else False)

   
    ##TODO Refactor this , get rid of one of the 2 dics below 

    @staticmethod
    def to_json():
        _dic = {}
        for val in (Vehicle_Enum):
            _temp_inner= {}
            for i in (val.value):
                _temp_inner[i.name] = i.value
            _dic[val.name] = _temp_inner
        return json.dumps(_dic,indent=4)

    
    @staticmethod ## This is just a temp thing, to display use teh to_json
    def save_json():
        _data = Vehicle_Enum.to_json()
        path  = os.getcwd() ## TODO implement path if needed later
        #filename = "vehicle_enum_" +ExtensionMethods.generate_filename()+".json" 
        filename = ExtensionMethods.generate_filename("vehicle_enum","json")
        filepath = os.path.join(os.getcwd(),filename) # fixed_nam
        file = open(filepath, "w")
        file.write(_data)
        file.close()
        print(f"The data has been printed to {filepath}")

    @staticmethod
    def get_desc_dic():
        '''Get the descriptions of the sub enums of the Vehicle Enum '''
        _dic = {}
        for val in (Vehicle_Enum):
            _dic[val.name]= val.value.__doc__
        return _dic


    @staticmethod
    def get_description(col=None):
        _dict = Vehicle_Enum.get_desc_dic() # this is expensive 
        if col in _dict.keys():
            return _dict[col]
        else:
            return "Key Not Found"

    @staticmethod
    def get_dic():
        _dic = {}
        for val in (Vehicle_Enum):
            _temp_inner = {}
            for i in (val.value):
                _temp_inner[i.name]= i.value
            _dic[val.name] = _temp_inner
        return _dic

    @staticmethod
    def get_col_dic(col=None):
        _dic = Vehicle_Enum.get_dic()
        if col in _dic.keys():
            return _dic[col]
        else:
            return "Key Not Found"

    @staticmethod
    def enum_category_check(col=None):
        if col is None:
            return "Sub Enum not found"
        if col in Vehicle_Enum.__members__:
            inner_enum_class = Vehicle_Enum[col].value
            return inner_enum_class.IsCategory()
        else:
            return "Col not found"
            
        

    @staticmethod
    def display():
        print("Vehicles Printed")
# Out:
# CPU times: user 2.03 ms, sys: 4 µs, total: 2.04 ms
# Wall time: 1.99 ms

# %%
'''These are dummy inplace enum definitions for the corresponding enums '''
class User_Enum(Enum):
    '''User stuff''' ##TODO add as required
    @staticmethod
    def display():
        print("User")
        
class Place_Enum(Enum):
    '''Place Enum'''
    @staticmethod
    def display():
        print("Place")

class Character_Enum(Enum):
    '''Characteristic Enum'''
    @staticmethod
    def display():
        print("Character")

# %%
###IMPORTANT
### Meta Enum allows some parts of the code to be generalized, change or add enums to 
###TODO : Refactor : Make a base class (overkill??)
class Meta_Enum(Enum):
    VEHICLES = Vehicle_Enum
    USERS = User_Enum
    PLACE = Place_Enum
    CHARACTER = Character_Enum

    @staticmethod
    def display(en = 'VEHICLES'):
        if en in Meta_Enum.__members__:
            enum_class = Meta_Enum[en].value  
            enum_class.display()  
        else:
            print(f"'{en}' is not a valid member of Meta_Enum.")

# %%
# %%time
class DataFrameExplorer:
    def __init__(self, df, filename=None, which_type='VEHICLES'):
        self.df = df
        self.which_type = which_type  # allows for generalizing the type for which meta_enum // See Meta_Enums
        # TODO add filepaths and name : currently we decide the path and name
        self.normal_columns = [
            'Column_Number', 'Name_of_Column', 'Variable_Type', 'Description',
            'Percentage_Missing_Values', 'Cat_or_Quant', 'Comments', 'Enum_Category_Check'
        ]
        if filename is None:
            self.filename = "DFE_UNAMED" + ExtensionMethods.generate_filename()
        else:
            self.filename = ExtensionMethods.get_file_name_without_extension(filename)
        self.dirpath = self.create_dir()
        self.work_tuple = self.run_workbook()

    def create_dir(self):
        dirpath = os.path.join(os.getcwd(), self.filename)
        if not os.path.exists(dirpath):
            os.makedirs(dirpath)
        return dirpath

    def run_workbook(self):
        wb = openpyxl.Workbook()
        ws = wb.active
        first_row = ("Name of the file", self.filename)
        second_row = ("Num of Rows of the DataFrame", len(self.df.index))
        third_row = ("Index col of the DataFrame", self.df.index.name)
        fourth_row = ("Columns of the DataFrame", ", ".join(self.df.columns))
        ws.append(first_row)
        ws.append(second_row)
        ws.append(third_row)
        ws.append(fourth_row)
        ws.append(self.normal_columns)
        return wb, ws

    def explore(self):
        if isinstance(self.df, pd.DataFrame):
            self.explore_pandas()
        elif isinstance(self.df, pl.DataFrame):
            self.explore_polars()
        else:
            print("Unsupported DataFrame type.")

    def explore_pandas(self):
        print("DataFrame Info:")
        self.df.info()

        print("\nNull Values per Column:")
        null_counts = self.df.isnull().sum()
        print(null_counts)

        print("\nNormal Values per Column:")
        normal_counts = self.df.notnull().sum()
        print(normal_counts)

        print("\nDescriptive Statistics:")
        print(self.df.describe(include='all'))

        categorical_cols = self.df.select_dtypes(include=['object']).columns
        print("\nValue Counts for Categorical Columns:")
        for col in categorical_cols:
            print(f"\nColumn: {col}")
            print(self.df[col].value_counts())

        print("Duplicate Check:")
        duplicates = self.df[self.df.duplicated()]
        print(f"Number of duplicate rows: {duplicates.shape[0]}")
        if not duplicates.empty:
            print("\nDuplicate Rows:")
            print(duplicates)

    def save_summary(self):
        wb, ws = self.work_tuple
        for index, col in enumerate(self.df.columns):
            name_col = col
            col_type = self.df[col].dtype
            dec = Meta_Enum[self.which_type].value.get_description(col)
            percentage_missing = (self.df[col].isnull().sum() / len(self.df)) * 100
            cat_or_quant = 'Categorical' if (col_type == 'object' or col_type == 'category') else 'Quantitative'
            print(cat_or_quant)
            comments = "Add Comments"
            check = Meta_Enum[self.which_type].value.enum_category_check(col)
            row_data = [
                index + 1, str(name_col), str(col_type), str(dec),
                str(percentage_missing), str(cat_or_quant), comments, str(check)
            ]
            ws.append(row_data)
            print(f"Summary for {col} is done")

        fp = os.path.join(self.dirpath, f"Data_Audit_Summary_for_{self.filename}.xlsx")
        wb.save(fp)
        print(f"Finished creating the excel worksheet for {self.filename}")

    def convert_single_col_to_cat(self, data=None, col_to_convert=None): # refactor this , this is chaos
        if data is None:
            return "Data Not found cannot convert single column"
        if col_to_convert is None:
            return "Nothing to Convert"

        if col_to_convert not in data.columns:
            return "Column not Found"

        _enum_dic = Meta_Enum[self.which_type].value.get_dic()
        if col_to_convert not in _enum_dic.keys():
            return "Column not Found in Enum Key Values"

        if not Meta_Enum[self.which_type].value.enum_category_check(col_to_convert):
            return "Cannot convert a Non Categorical data"

        _enum_col = _enum_dic[col_to_convert]
        _dic = {value: key for key, value in _enum_dic[col_to_convert].items()}

        _data = data[col_to_convert].copy()
        _data = _data.map(_dic)
        return _data

    def convert_cols(self, data=None):
        if data is None:
            return "No data Found hence conversion to Categories will fail"
        for col in data.columns:
            _temp = self.convert_single_col_to_cat(data, col)
            if not (isinstance(_temp, pd.DataFrame) or isinstance(_temp, pd.Series)):
                print(_temp)
            else:
                _new_col = "new_" + str(col)
                data[_new_col] = _temp
        return data

    def get_slice(self, data=None, percentage=0.25):
        if data is None:
            return "Error: Need data"
        num_samples = int(len(data) * percentage)
        return data.sample(n=num_samples, random_state=random_state)

    def _plot_summary(self, data=None):
        '''This creates plots for different combinations of data , This is private but not strictly enforced'''
        if data is None:
            return "Data not found"
        cat_cols = data.select_dtypes(include=['category', 'object']).columns
        num_cols = data.select_dtypes(exclude=['category', 'object', 'datetime']).columns
        print(f"cat cols {cat_cols}")
        print(f"num cols {num_cols}")

        if num_cols.size > 0:
            try:
                correlation = data[num_cols].corr()
                plt.figure()
                ax = sns.heatmap(correlation, annot=True)
                ax.set(xlabel="", ylabel="")
                ax.xaxis.tick_top()
                ax.set_title("Heatmap of Corr Data")
                filepath = os.path.join(self.dirpath, ExtensionMethods.generate_filename("heatmap", "png"))
                plt.savefig(filepath)
                plt.close()
            except Exception as ex:
                print(f"Error creating plot for {filepath}: {ex}")

        for cat in cat_cols:
            try:
                plt.figure()
                fig = sns.histplot(data[cat])
                fig.set(xlabel="cat", ylabel="Freq")
                fig.set_title(f"Distribution of {cat}")
                filepath = os.path.join(self.dirpath, ExtensionMethods.generate_filename(f"Distribution_{cat}", "png"))
                plt.savefig(filepath)
                plt.close()
                print(f"Finished dis plot of {cat}")
            except Exception as ex:
                print(f"Error creating plot for {cat}: {ex}")

        for num in num_cols:
            try:
                plt.figure()
                fig = sns.kdeplot(data=data, x=num)
                fig.set_title(f"KDE Plot of {num}")
                filepath = os.path.join(self.dirpath, ExtensionMethods.generate_filename(f"KDEPlot_{num}", "png"))
                plt.savefig(filepath)
                plt.close()
                print(f"Finished kde plot of {num}")
            except Exception as ex:
                print(f"Error creating plot for {num}: {ex}")

    def save_profiling_report(self):
        filename = f"ProfilingReport_{self.filename}"
        filepath = os.path.join(self.dirpath, ExtensionMethods.generate_filename(filename, "html"))
        profile = ProfileReport(self.df, title=filename)
        profile.to_file(filepath)
        print(f"Finished Profile Report {filename}")

    def plot_me(self, col_drop=None):
        data = self.df.copy()
        if col_drop is not None:
            data = data.drop(columns=col_drop)
        for col in data.columns:
            if data[col].is_unique:
                print(f"Dropping {col} as its not categorical or is unique")
                data = data.drop(columns=col)
            print(f"Converting {col} to a category for better comprehension")
        self._plot_summary(self.convert_cols(data))

    def save_enum(self):
        Meta_Enum[self.which_type].value.save_json()
        print(f"Saved the Enums for type{self.which_type}")

    def _do_zip(self): ## Just for testing // Remove this later 
        dirpath = os.path.join(os.getcwd(), self.filename)
        if os.path.exists(dirpath):
            archive_filename = self.filename
            shutil.make_archive(archive_filename, 'zip', root_dir=dirpath)
            print(f"Zipped Up: {archive_filename}.zip")
        else:
            raise FileNotFoundError(f"Directory not found: {dirpath}")
             

    def _do_magic(self): # multithread this 
        '''This a magic function that does everything '''
        try:
            print("Do all the magic in this function") 
            print(f"\n=== Starting the spell for {self.which_type} ===")
            self.explore()
            print(f"\n=== Finished {self.explore.__name__} ===")
            self.save_summary()
            print(f"\n=== Finished {self.save_summary.__name__} ===")
            self.plot_me()
            print(f"\n=== Finished {self.plot_me.__name__} ===")
            self.save_profiling_report()
            print(f"\n=== Finished {self.save_profiling_report.__name__} ===")
            self._do_zip()
            print(f"\n=== Finished the Zip Process")
            
            
        except Exception as ex:
            return (f"Error as {ex}")
        finally:
            return (f"\n=== All Done for {self.filename} ===")
# Out:
# CPU times: user 36 µs, sys: 0 ns, total: 36 µs
# Wall time: 39.3 µs

# %%
# %%time
#filename_2019 = filepaths['vehicles'][2019]
#vehicles_df  = pd.read_csv(filename_2019, sep=';',index_col ='Num_Acc')
#explorer  = DataFrameExplorer(vehicles_df,filename=filename_2019)
#explorer._do_magic()
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.39 µs

# %%
# %%time
## Call a ProcessExecutor to do it all parallely
years = [2019,2020,2021,2022,2023]
file = 'vehicles' # change this to whatever your file is


def do_something(_file='vehicles',_year=2019,_index='Num_Acc'):
    _filename= filepaths[_file][_year]
    print(f"\n=== File {_filename} is starting up ===")
    _df = pd.read_csv(_filename,sep=';', index_col=_index)
    explorer = DataFrameExplorer(_df,filename=_filename) ## Don't forget which_type
    explorer._do_magic()
    

print("\n=== ProcessPoolExecutor Started ===")
with ProcessPoolExecutor(max_workers=3) as executor:
    ## Don't forget to change the stuff below
    futures = [executor.submit(do_something,file,year,'Num_Acc') for year in years]
    for future in as_completed(futures):
        try:
            result = future.result()
            print("Future Result:", result)
        except Exception as ex:
            print(f"Error in {ex}")
# Out:
# === ProcessPoolExecutor Started ===
#
# === File /kaggle/input/nov24-bds-roadies-users/vehicules-2019.csv is starting up ===
# === File /kaggle/input/nov24-bds-roadies-users/vehicules-2020.csv is starting up ===
# === File /kaggle/input/nov24-bds-roadies-users/vehicules-2021.csv is starting up ===
#
#
# Do all the magic in this function
#
# === Starting the spell for VEHICLES ===
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81066 entries, 202000000001 to 202000047744
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_vehicule  81066 non-null  object
#  1   num_veh      81066 non-null  object
#  2   senc         81066 non-null  int64
#  3   catv         81066 non-null  int64
#  4   obs          81066 non-null  int64
#  5   obsm         81066 non-null  int64
#  6   choc         81066 non-null  int64
#  7   manv         81066 non-null  int64
#  8   motor        81066 non-null  int64
#  9   occutc       621 non-null    float64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 6.8+ MB
#
# Null Values per Column:Do all the magic in this function
#
# Do all the magic in this function
# === Starting the spell for VEHICLES ===
#
#
# === Starting the spell for VEHICLES ===DataFrame Info:
#
# DataFrame Info:
# id_vehicule        0
# num_veh            0
# senc               0
# catv               0
# obs                0
# obsm               0
# choc               0
# manv               0
# motor              0
# occutc         80445
# dtype: int64
#
# Normal Values per Column:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100710 entries, 201900000001 to 201900058840
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id_vehicule  100710 non-null  object
#  1   num_veh      100710 non-null  object
#  2   senc         100710 non-null  int64
#  3   catv         100710 non-null  int64
#  4   obs          100710 non-null  int64
#  5   obsm         100710 non-null  int64
#  6   choc         100710 non-null  int64
#  7   manv         100710 non-null  int64
#  8   motor        100710 non-null  int64
#  9   occutc       892 non-null     float64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 8.5+ MB
# id_vehicule    81066
# num_veh        81066
# senc           81066
# catv           81066
# obs            81066
# obsm           81066
# choc           81066
# manv           81066
# motor          81066
# occutc           621
# dtype: int64
# Null Values per Column:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 97315 entries, 202100000001 to 202100056518
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_vehicule  97315 non-null  object
#  1   num_veh      97315 non-null  object
#  2   senc         97315 non-null  int64
#  3   catv         97315 non-null  int64
#  4   obs          97315 non-null  int64
#  5   obsm         97315 non-null  int64
#  6   choc         97315 non-null  int64
#  7   manv         97315 non-null  int64
#  8   motor        97315 non-null  int64
#  9   occutc       744 non-null    float64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 8.2+ MB
#
# Descriptive Statistics:
# Null Values per Column:
#
# id_vehicule        0
# num_veh            0
# senc               0
# catv               0
# obs                0
# obsm               0
# choc               0
# manv               0
# motor              0
# occutc         99818
# dtype: int64
#
# Normal Values per Column:
# id_vehicule        0
# num_veh            0
# senc               0
# catv               0
# obs                0
# obsm               0
# choc               0
# manv               0
# motor              0
# occutc         96571
# dtype: int64
#
# Normal Values per Column:
# id_vehicule    100710
# num_veh        100710
# senc           100710
# catv           100710
# obs            100710
# obsm           100710
# choc           100710
# manv           100710
# motor          100710
# occutc            892
# dtype: int64
#
# Descriptive Statistics:
# id_vehicule    97315
# num_veh        97315
# senc           97315
# catv           97315
# obs            97315
# obsm           97315
# choc           97315
# manv           97315
# motor          97315
# occutc           744
# dtype: int64
#
# Descriptive Statistics:
#         id_vehicule num_veh          senc          catv           obs  \
# count         81066   81066  81066.000000  81066.000000  81066.000000
# unique        81066      51           NaN           NaN           NaN
# top     154 742 274     A01           NaN           NaN           NaN
# freq              1   46880           NaN           NaN           NaN
# mean            NaN     NaN      1.529902     12.909086      1.049059
# std             NaN     NaN      0.831473     13.649846      3.184195
# min             NaN     NaN     -1.000000     -1.000000     -1.000000
# 25%             NaN     NaN      1.000000      7.000000      0.000000
# 50%             NaN     NaN      1.000000      7.000000      0.000000
# 75%             NaN     NaN      2.000000     10.000000      0.000000
# max             NaN     NaN      3.000000     99.000000     17.000000
#
#                 obsm          choc          manv         motor      occutc
# count   81066.000000  81066.000000  81066.000000  81066.000000  621.000000
# unique           NaN           NaN           NaN           NaN         NaN
# top              NaN           NaN           NaN           NaN         NaN
# freq             NaN           NaN           NaN           NaN         NaN
# mean        1.651815      2.898885      7.205746      1.233119    1.663446
# std         1.280112      2.435055      8.041962      1.171552    2.617762
# min        -1.000000     -1.000000     -1.000000     -1.000000    0.000000
# 25%         1.000000      1.000000      1.000000      1.000000    1.000000
# 50%         2.000000      2.000000      2.000000      1.000000    1.000000
# 75%         2.000000      4.000000     15.000000      1.000000    1.000000
# max         9.000000      9.000000     26.000000      6.000000   34.000000
#
# Value Counts for Categorical Columns:
#
# Column: id_vehicule
#        id_vehicule num_veh          senc          catv           obs  \
# count        97315   97315  97315.000000  97315.000000  97315.000000
# unique       97315      53           NaN           NaN           NaN
# top        201 764     A01           NaN           NaN           NaN
# freq             1   55564           NaN           NaN           NaN
# mean           NaN     NaN      1.550542     13.134882      0.981771
# std            NaN     NaN      0.822866     13.858457      3.066642
# min            NaN     NaN     -1.000000     -1.000000     -1.000000
# 25%            NaN     NaN      1.000000      7.000000      0.000000
# 50%            NaN     NaN      1.000000      7.000000      0.000000
# 75%            NaN     NaN      2.000000     10.000000      0.000000
# max            NaN     NaN      3.000000     99.000000     17.000000
#
#                 obsm          choc          manv         motor      occutc
# count   97315.000000  97315.000000  97315.000000  97315.000000  744.000000
# unique           NaN           NaN           NaN           NaN         NaN
# top              NaN           NaN           NaN           NaN         NaN
# freq             NaN           NaN           NaN           NaN         NaN
# mean        1.685249      2.887838      7.235431      1.271890    1.653226
# std         1.275214      2.415910      8.079427      1.049414    1.951130
# min        -1.000000     -1.000000     -1.000000     -1.000000    0.000000
# 25%         1.000000      1.000000      1.000000      1.000000    1.000000
# 50%         2.000000      2.000000      2.000000      1.000000    1.000000
# 75%         2.000000      4.000000     15.000000      1.000000    2.000000
# max         9.000000      9.000000     26.000000      6.000000   28.000000
#
# Value Counts for Categorical Columns:
#
# Column: id_vehicule
#         id_vehicule num_veh           senc           catv            obs  \
# count        100710  100710  100710.000000  100710.000000  100710.000000
# unique       100710      48            NaN            NaN            NaN
# top     138 306 524     A01            NaN            NaN            NaN
# freq              1   57666            NaN            NaN            NaN
# mean            NaN     NaN       1.557075      12.632817       0.990646
# std             NaN     NaN       0.833885      12.800755       3.088678
# min             NaN     NaN      -1.000000       0.000000      -1.000000
# 25%             NaN     NaN       1.000000       7.000000       0.000000
# 50%             NaN     NaN       1.000000       7.000000       0.000000
# 75%             NaN     NaN       2.000000      10.000000       0.000000
# max             NaN     NaN       3.000000      99.000000      17.000000
#
#                  obsm           choc           manv          motor      occutc
# count   100710.000000  100710.000000  100710.000000  100710.000000  892.000000
# unique            NaN            NaN            NaN            NaN         NaN
# top               NaN            NaN            NaN            NaN         NaN
# freq              NaN            NaN            NaN            NaN         NaN
# mean         1.627098       2.926045       7.267401       1.171353    1.818386
# std          1.120068       2.421520       8.077319       1.112887    2.858931
# min         -1.000000      -1.000000      -1.000000      -1.000000    0.000000
# 25%          1.000000       1.000000       1.000000       1.000000    1.000000
# 50%          2.000000       2.000000       2.000000       1.000000    1.000000
# 75%          2.000000       4.000000      15.000000       1.000000    1.000000
# max          9.000000       9.000000      26.000000       6.000000   33.000000
#
# Value Counts for Categorical Columns:
#
# Column: id_vehicule
# id_vehicule
# 154 742 274    1
# 154 686 317    1
# 154 686 309    1
# 154 686 311    1
# 154 686 313    1
#               ..
# 154 714 291    1
# 154 714 290    1
# 154 714 292    1
# 154 714 293    1
# 154 658 350    1
# Name: count, Length: 81066, dtype: int64id_vehicule
# 201 764    1
# 134 422    1
# 134 412    1
# 134 414    1
# 134 413    1
#           ..
# 167 981    1
# 167 983    1
# 167 982    1
# 167 985    1
# 100 883    1
# Name: count, Length: 97315, dtype: int64
#
#
# Column: num_veh
# Column: num_veh
#
# num_veh
# A01     55564
# B01     34784
# C01      3998
# Z01      1469
# D01       899
# E01       267
# F01        80
# Y01        73
# G01        34
# T01        24
# H01        19
# I01        10
# X01         9
# J01         8
# K01         7
# M01         5
# L01         5
# SA01        4
# [01         4
# FA01        4
# P01         4
# TA01        3
# V01         3
# BA01        2
# CA01        2
# AA01        2
# DA01        2
# RA01        2
# MB01        2
# ZZ01        2
# VB01        2
# IA01        1
# KD01        1
# PA01        1
# ]01         1
# N01         1
# S01         1
# R01         1
# Q01         1
# O01         1
# EB01        1
# U01         1
# LA01        1
# TB01        1
# KA01        1
# YA01        1
# AB01        1
# SB01        1
# GA01        1
# XA01        1
# NA01        1
# FB01        1
# GB01        1
# Name: count, dtype: int64num_veh
# A01     46880
# B01     28459
# C01      3231
# Z01      1373
# D01       696
# E01       169
# Y01        67
# F01        64
# G01        24
# T01        17
# X01        12
# H01         9
# AB01        5
# CA01        5
# AA01        5
# BB01        4
# MA01        4
# [01         3
# SA01        3
# SB01        2
# LA01        2
# I01         2
# PA01        2
# VB01        1
# GA01        1
# MB01        1
# VA01        1
# DB01        1
# CC01        1
# J01         1
# W01         1
# IB01        1
# DA01        1
# FA01        1
# PB01        1
# RA01        1
# HB01        1
# AY01        1
# M01         1
# TB01        1
# P01         1
# EA01        1
# V01         1
# MV01        1
# MC01        1
# WB01        1
# EB01        1
# BA01        1
# NA01        1
# CB01        1
# HA01        1
# Name: count, dtype: int64
# Duplicate Check:
#
# Duplicate Check:
# Number of duplicate rows: 0
#
# === Finished explore ===
# Categorical
# Number of duplicate rows: 0
# Summary for id_vehicule is done
#
# === Finished explore ===
# Categorical
# Summary for num_veh is done
# CategoricalQuantitative
#
# Summary for id_vehicule is doneSummary for senc is done
#
# Quantitativeid_vehicule
# 138 306 524    1
# 138 232 311    1
# 138 232 313    1
# 138 232 319    1
# 138 232 318    1
#               ..
# 138 269 643    1
# 138 269 642    1
# 138 269 646    1
# 138 269 645    1
# 137 982 130    1
# Name: count, Length: 100710, dtype: int64
#
#
# Column: num_vehSummary for catv is doneCategorical
#
#
# Quantitative
# Summary for num_veh is doneSummary for obs is done
#
# QuantitativeQuantitative
#
# Summary for obsm is doneSummary for senc is done
#
# QuantitativeQuantitative
#
# Summary for catv is donenum_veh
# A01     57666
# B01     35355
# C01      4482
# Z01      1666
# D01       975
# E01       244
# F01        91
# Y01        66
# G01        34
# H01        20
# T01        19
# I01        13
# X01        10
# L01         6
# K01         6
# M01         5
# J01         5
# ZZ01        3
# N01         3
# CB01        3
# W01         3
# O01         3
# TB01        2
# U01         2
# P01         2
# Q01         2
# FB01        2
# [01         2
# LB01        1
# ZB01        1
# BB01        1
# AA01        1
# DA01        1
# AB01        1
# VF01        1
# \01         1
# VB01        1
# BA01        1
# RC01        1
# MA01        1
# GB01        1
# R01         1
# TC01        1
# RA01        1
# MB01        1
# V01         1
# PB01        1
# BC01        1
# Name: count, dtype: int64Summary for choc is done
#
#
# Duplicate Check:QuantitativeQuantitative
#
#
# Summary for obs is doneSummary for manv is done
#
# QuantitativeQuantitative
#
# Summary for obsm is done
# Summary for motor is done
# Quantitative
# QuantitativeSummary for choc is done
# Summary for occutc is done
#
# Quantitative
# Summary for manv is done
# Quantitative
# Summary for motor is done
# Quantitative
# Summary for occutc is doneFinished creating the excel worksheet for vehicules-2020
#
#
# === Finished save_summary ===
# Finished creating the excel worksheet for vehicules-2021
# Number of duplicate rows: 0
# === Finished save_summary ===
#
#
# === Finished explore ===
# Dropping id_vehicule as its not categorical or is unique
# Categorical
# Summary for id_vehicule is done
# Converting id_vehicule to a category for better comprehension
# Dropping id_vehicule as its not categorical or is unique
# CategoricalConverting num_veh to a category for better comprehension
#
# Converting id_vehicule to a category for better comprehensionSummary for num_veh is doneConverting senc to a category for better comprehension
#
#
# Converting catv to a category for better comprehensionQuantitative
#
# Converting obs to a category for better comprehensionConverting num_veh to a category for better comprehensionSummary for senc is done
#
#
# Converting obsm to a category for better comprehensionConverting senc to a category for better comprehension
#
# QuantitativeConverting choc to a category for better comprehensionConverting catv to a category for better comprehension
#
# Summary for catv is done
#
# Converting manv to a category for better comprehensionConverting obs to a category for better comprehensionQuantitative
#
#
# Converting motor to a category for better comprehensionSummary for obs is doneConverting obsm to a category for better comprehension
#
#
# Converting occutc to a category for better comprehensionQuantitative
# Converting choc to a category for better comprehension
# Cannot convert a Non Categorical data
#
# Summary for obsm is doneConverting manv to a category for better comprehension
#
# Quantitative
# Converting motor to a category for better comprehensionSummary for choc is done
#
# Converting occutc to a category for better comprehensionQuantitative
#
# Summary for manv is doneCannot convert a Non Categorical data
#
# Quantitative
# Summary for motor is done
# Cannot convert a Non Categorical dataQuantitative
#
# Summary for occutc is done
# Cannot convert a Non Categorical data
# Finished creating the excel worksheet for vehicules-2019
#
# === Finished save_summary ===
# cat cols Index(['num_veh', 'new_senc', 'new_catv', 'new_obs', 'new_obsm', 'new_choc',
#        'new_manv', 'new_motor'],
#       dtype='object')
# num cols Index(['senc', 'catv', 'obs', 'obsm', 'choc', 'manv', 'motor', 'occutc'], dtype='object')
# Dropping id_vehicule as its not categorical or is unique
# Converting id_vehicule to a category for better comprehension
# cat cols Index(['num_veh', 'new_senc', 'new_catv', 'new_obs', 'new_obsm', 'new_choc',
#        'new_manv', 'new_motor'],
#       dtype='object')
# Converting num_veh to a category for better comprehensionnum cols Index(['senc', 'catv', 'obs', 'obsm', 'choc', 'manv', 'motor', 'occutc'], dtype='object')
#
# Converting senc to a category for better comprehension
# Converting catv to a category for better comprehension
# Converting obs to a category for better comprehension
# Converting obsm to a category for better comprehension
# Converting choc to a category for better comprehension
# Converting manv to a category for better comprehension
# Converting motor to a category for better comprehension
# Converting occutc to a category for better comprehension
# Cannot convert a Non Categorical data
# Cannot convert a Non Categorical data
# cat cols Index(['num_veh', 'new_senc', 'new_catv', 'new_obs', 'new_obsm', 'new_choc',
#        'new_manv', 'new_motor'],
#       dtype='object')
# num cols Index(['senc', 'catv', 'obs', 'obsm', 'choc', 'manv', 'motor', 'occutc'], dtype='object')
# Finished dis plot of num_veh
# Finished dis plot of num_veh
# Finished dis plot of num_veh
# Finished dis plot of new_senc
# Finished dis plot of new_senc
# Finished dis plot of new_senc
# Finished dis plot of new_catv
# Finished dis plot of new_catv
# Finished dis plot of new_catv
# Finished dis plot of new_obs
# Finished dis plot of new_obs
# Finished dis plot of new_obs
# Finished dis plot of new_obsm
# Finished dis plot of new_obsm
# Finished dis plot of new_obsm
# Finished dis plot of new_choc
# Finished dis plot of new_choc
# Finished dis plot of new_choc
# Finished dis plot of new_manv
# Finished dis plot of new_manv
# Finished dis plot of new_motor
# Finished dis plot of new_manv
# Finished dis plot of new_motor
# Finished kde plot of senc
# Finished dis plot of new_motor
# Finished kde plot of senc
# Finished kde plot of catv
# Finished kde plot of senc
# Finished kde plot of catv
# Finished kde plot of obs
# Finished kde plot of catv
# Finished kde plot of obsm
# Finished kde plot of obs
# Finished kde plot of obs
# Finished kde plot of choc
# Finished kde plot of obsm
# Finished kde plot of obsm
# Finished kde plot of manv
# Finished kde plot of choc
# Finished kde plot of choc
# Finished kde plot of motor
# Error creating plot for occutc: cannot reindex on an axis with duplicate labels
#
# === Finished plot_me ===
# Finished kde plot of manvFinished kde plot of manv
#
# Finished kde plot of motor
# Finished kde plot of motor
# Error creating plot for occutc: cannot reindex on an axis with duplicate labels
#
# === Finished plot_me ===
# Error creating plot for occutc: cannot reindex on an axis with duplicate labels
#
# === Finished plot_me ===
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Finished Profile Report ProfilingReport_vehicules-2020
#
# === Finished save_profiling_report ===
# Zipped Up: vehicules-2020.zip
#
# === Finished the Zip Process
#
# === File /kaggle/input/nov24-bds-roadies-users/vehicules-2022.csv is starting up ===
# Future Result: None
# Do all the magic in this function
#
# === Starting the spell for VEHICLES ===
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94493 entries, 202200000001 to 202200055302
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_vehicule  94493 non-null  object
#  1   num_veh      94493 non-null  object
#  2   senc         94493 non-null  int64
#  3   catv         94493 non-null  int64
#  4   obs          94493 non-null  int64
#  5   obsm         94493 non-null  int64
#  6   choc         94493 non-null  int64
#  7   manv         94493 non-null  int64
#  8   motor        94493 non-null  int64
#  9   occutc       817 non-null    float64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 7.9+ MB
#
# Null Values per Column:
# id_vehicule        0
# num_veh            0
# senc               0
# catv               0
# obs                0
# obsm               0
# choc               0
# manv               0
# motor              0
# occutc         93676
# dtype: int64
#
# Normal Values per Column:
# id_vehicule    94493
# num_veh        94493
# senc           94493
# catv           94493
# obs            94493
# obsm           94493
# choc           94493
# manv           94493
# motor          94493
# occutc           817
# dtype: int64
#
# Descriptive Statistics:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Finished Profile Report ProfilingReport_vehicules-2021
#
# === Finished save_profiling_report ===
#        id_vehicule num_veh          senc          catv           obs  \
# count        94493   94493  94493.000000  94493.000000  94493.000000
# unique       94493      47           NaN           NaN           NaN
# top        813 952     A01           NaN           NaN           NaN
# freq             1   54418           NaN           NaN           NaN
# mean           NaN     NaN      1.573439     13.456245      1.027579
# std            NaN     NaN      0.822237     14.322038      3.128954
# min            NaN     NaN     -1.000000     -1.000000     -1.000000
# 25%            NaN     NaN      1.000000      7.000000      0.000000
# 50%            NaN     NaN      1.000000      7.000000      0.000000
# 75%            NaN     NaN      2.000000     10.000000      0.000000
# max            NaN     NaN      3.000000     99.000000     17.000000
#
#                 obsm          choc          manv         motor      occutc
# count   94493.000000  94493.000000  94493.000000  94493.000000  817.000000
# unique           NaN           NaN           NaN           NaN         NaN
# top              NaN           NaN           NaN           NaN         NaN
# freq             NaN           NaN           NaN           NaN         NaN
# mean        1.664515      2.876837      6.924270      1.320352    1.919217
# std         1.265675      2.419628      7.888078      1.080011    3.432234
# min        -1.000000     -1.000000     -1.000000     -1.000000    1.000000
# 25%         1.000000      1.000000      1.000000      1.000000    1.000000
# 50%         2.000000      2.000000      2.000000      1.000000    1.000000
# 75%         2.000000      4.000000     15.000000      1.000000    1.000000
# max         9.000000      9.000000     26.000000      6.000000   38.000000
#
# Value Counts for Categorical Columns:
#
# Column: id_vehicule
# id_vehicule
# 813 952    1
# 748 391    1
# 748 383    1
# 748 379    1
# 748 384    1
#           ..
# 781 102    1
# 781 100    1
# 781 104    1
# 781 103    1
# 715 630    1
# Name: count, Length: 94493, dtype: int64
#
# Column: num_veh
# num_veh
# A01     54418
# B01     33503
# C01      3744
# Z01      1439
# D01       832
# E01       250
# Y01        87
# F01        84
# G01        35
# H01        13
# X01        13
# [01        11
# T01        10
# I01         6
# ZZ01        3
# WX01        3
# JA01        3
# V01         3
# P01         2
# J01         2
# PB01        2
# \01         2
# LA01        2
# FA01        2
# M01         2
# W01         1
# L01         1
# VA01        1
# LB01        1
# UB01        1
# OB01        1
# PA01        1
# MA01        1
# S01         1
# U01         1
# RB01        1
# R01         1
# Q01         1
# O01         1
# N01         1
# K01         1
# GA01        1
# DA01        1
# IA01        1
# NA01        1
# XB01        1
# ZA01        1
# Name: count, dtype: int64
# Duplicate Check:
# Number of duplicate rows: 0
#
# === Finished explore ===
# Categorical
# Summary for id_vehicule is done
# Categorical
# Summary for num_veh is done
# Quantitative
# Zipped Up: vehicules-2021.zipSummary for senc is done
#
# === Finished the Zip Process
#
# Quantitative
#
# === File /kaggle/input/nov24-bds-roadies-users/vehicules-2023.csv is starting up ===Summary for catv is done
#
# Quantitative
# Summary for obs is done
# Quantitative
# Summary for obsm is done
# Quantitative
# Summary for choc is done
# Quantitative
# Summary for manv is done
# Quantitative
# Summary for motor is done
# Quantitative
# Summary for occutc is done
# Finished creating the excel worksheet for vehicules-2022
#
# === Finished save_summary ===
# Dropping id_vehicule as its not categorical or is unique
# Converting id_vehicule to a category for better comprehension
# Converting num_veh to a category for better comprehension
# Converting senc to a category for better comprehension
# Converting catv to a category for better comprehension
# Converting obs to a category for better comprehension
# Converting obsm to a category for better comprehension
# Converting choc to a category for better comprehension
# Converting manv to a category for better comprehension
# Converting motor to a category for better comprehension
# Converting occutc to a category for better comprehension
# Cannot convert a Non Categorical data
# Future Result: None
# Cannot convert a Non Categorical data
# cat cols Index(['num_veh', 'new_senc', 'new_catv', 'new_obs', 'new_obsm', 'new_choc',
#        'new_manv', 'new_motor'],
#       dtype='object')
# num cols Index(['senc', 'catv', 'obs', 'obsm', 'choc', 'manv', 'motor', 'occutc'], dtype='object')
# Do all the magic in this function
#
# === Starting the spell for VEHICLES ===
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93585 entries, 202300000001 to 202300054822
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_vehicule  93585 non-null  object
#  1   num_veh      93585 non-null  object
#  2   senc         93585 non-null  int64
#  3   catv         93585 non-null  int64
#  4   obs          93585 non-null  int64
#  5   obsm         93585 non-null  int64
#  6   choc         93585 non-null  int64
#  7   manv         93585 non-null  int64
#  8   motor        93585 non-null  int64
#  9   occutc       838 non-null    float64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 7.9+ MB
#
# Null Values per Column:
# id_vehicule        0
# num_veh            0
# senc               0
# catv               0
# obs                0
# obsm               0
# choc               0
# manv               0
# motor              0
# occutc         92747
# dtype: int64
#
# Normal Values per Column:
# id_vehicule    93585
# num_veh        93585
# senc           93585
# catv           93585
# obs            93585
# obsm           93585
# choc           93585
# manv           93585
# motor          93585
# occutc           838
# dtype: int64
#
# Descriptive Statistics:
#         id_vehicule num_veh          senc          catv           obs  \
# count         93585   93585  93585.000000  93585.000000  93585.000000
# unique        93585      46           NaN           NaN           NaN
# top     155 680 557     A01           NaN           NaN           NaN
# freq              1   54043           NaN           NaN           NaN
# mean            NaN     NaN      1.593589     13.679949      1.050307
# std             NaN     NaN      0.817015     14.636220      3.168680
# min             NaN     NaN     -1.000000     -1.000000     -1.000000
# 25%             NaN     NaN      1.000000      7.000000      0.000000
# 50%             NaN     NaN      1.000000      7.000000      0.000000
# 75%             NaN     NaN      2.000000     10.000000      0.000000
# max             NaN     NaN      3.000000     99.000000     17.000000
#
#                 obsm          choc          manv         motor      occutc
# count   93585.000000  93585.000000  93585.000000  93585.000000  838.000000
# unique           NaN           NaN           NaN           NaN         NaN
# top              NaN           NaN           NaN           NaN         NaN
# freq             NaN           NaN           NaN           NaN         NaN
# mean        1.655297      2.877117      6.772122      1.304515    2.103819
# std         1.258317      2.413490      7.792551      1.141443    4.372988
# min        -1.000000     -1.000000     -1.000000     -1.000000    0.000000
# 25%         1.000000      1.000000      1.000000      1.000000    1.000000
# 50%         2.000000      2.000000      2.000000      1.000000    1.000000
# 75%         2.000000      4.000000     14.000000      1.000000    1.000000
# max         9.000000      9.000000     26.000000      6.000000   65.000000
#
# Value Counts for Categorical Columns:
#
# Column: id_vehicule
# id_vehicule
# 155 680 557    1
# 155 615 771    1
# 155 615 773    1
# 155 615 777    1
# 155 615 776    1
#               ..
# 155 648 197    1
# 155 648 201    1
# 155 648 198    1
# 155 648 200    1
# 155 583 345    1
# Name: count, Length: 93585, dtype: int64
#
# Column: num_veh
# num_veh
# A01     54043
# B01     33503
# C01      3725
# Z01      1122
# D01       744
# E01       191
# Y01        84
# F01        53
# X01        19
# G01        19
# T01        13
# H01         7
# P01         6
# I01         4
# AB01        4
# CA01        3
# MA01        3
# EA01        3
# V01         2
# CB01        2
# RA01        2
# J01         2
# K01         2
# LB01        2
# PA01        2
# AA01        2
# M01         2
# AC01        2
# U01         2
# L01         1
# VB01        1
# _01         1
# BB01        1
# EB01        1
# NA01        1
# FA01        1
# VA01        1
# MB01        1
# OA01        1
# KA01        1
# RB01        1
# TB01        1
# BA01        1
# N01         1
# DA01        1
# TC01        1
# Name: count, dtype: int64
# Duplicate Check:
# Number of duplicate rows: 0
#
# === Finished explore ===
# Categorical
# Summary for id_vehicule is done
# Categorical
# Summary for num_veh is done
# Quantitative
# Summary for senc is done
# Quantitative
# Summary for catv is done
# Quantitative
# Summary for obs is done
# Quantitative
# Summary for obsm is done
# Quantitative
# Summary for choc is done
# Quantitative
# Summary for manv is done
# Quantitative
# Summary for motor is done
# Quantitative
# Summary for occutc is done
# Finished creating the excel worksheet for vehicules-2023
#
# === Finished save_summary ===
# Dropping id_vehicule as its not categorical or is unique
# Converting id_vehicule to a category for better comprehension
# Converting num_veh to a category for better comprehension
# Converting senc to a category for better comprehension
# Converting catv to a category for better comprehension
# Converting obs to a category for better comprehension
# Converting obsm to a category for better comprehension
# Converting choc to a category for better comprehension
# Converting manv to a category for better comprehension
# Converting motor to a category for better comprehension
# Converting occutc to a category for better comprehension
# Cannot convert a Non Categorical data
# Cannot convert a Non Categorical data
# cat cols Index(['num_veh', 'new_senc', 'new_catv', 'new_obs', 'new_obsm', 'new_choc',
#        'new_manv', 'new_motor'],
#       dtype='object')
# num cols Index(['senc', 'catv', 'obs', 'obsm', 'choc', 'manv', 'motor', 'occutc'], dtype='object')
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Finished Profile Report ProfilingReport_vehicules-2019
#
# === Finished save_profiling_report ===
# Zipped Up: vehicules-2019.zip
#
# === Finished the Zip Process
# Future Result: None
# Finished dis plot of num_veh
# Finished dis plot of new_senc
# Finished dis plot of num_veh
# Finished dis plot of new_senc
# Finished dis plot of new_catv
# Finished dis plot of new_catv
# Finished dis plot of new_obs
# Finished dis plot of new_obsm
# Finished dis plot of new_obs
# Finished dis plot of new_choc
# Finished dis plot of new_obsm
# Finished dis plot of new_choc
# Finished dis plot of new_manv
# Finished dis plot of new_manv
# Finished dis plot of new_motor
# Finished dis plot of new_motor
# Finished kde plot of senc
# Finished kde plot of senc
# Finished kde plot of catv
# Finished kde plot of catv
# Finished kde plot of obs
# Finished kde plot of obs
# Finished kde plot of obsm
# Finished kde plot of obsm
# Finished kde plot of choc
# Finished kde plot of choc
# Finished kde plot of manv
# Finished kde plot of manv
# Finished kde plot of motor
# Error creating plot for occutc: cannot reindex on an axis with duplicate labels
#
# === Finished plot_me ===
# Finished kde plot of motor
# Error creating plot for occutc: cannot reindex on an axis with duplicate labels
#
# === Finished plot_me ===
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Finished Profile Report ProfilingReport_vehicules-2022
#
# === Finished save_profiling_report ===
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Finished Profile Report ProfilingReport_vehicules-2023
#
# === Finished save_profiling_report ===
# Zipped Up: vehicules-2022.zip
#
# === Finished the Zip Process
# Zipped Up: vehicules-2023.zip
#
# === Finished the Zip Process
# Future Result: None
# Future Result: None
# CPU times: user 1.73 s, sys: 854 ms, total: 2.59 s
# Wall time: 2min 54s
